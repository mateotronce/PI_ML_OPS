# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time
from datetime import datetime
import numpy as np
import seaborn as sns
import string as string
import matplotlib.pyplot as plt

# %%
rev = pd.read_csv("reviews_analisadas.csv")
user = pd.read_csv("usuarios_juegos.csv")
game = pd.read_csv("juegos_limpios.csv")
nom = [str(rev),str(user),str(game)]

# %%
nombres = [rev,user,game]
nas=[]
sise=[]
regs=[]

for data in nombres:
  filename=df.columns
  for name in filename:
      print("Tamaño del dataset")
      print("------------------")
      regs.append(data.shape[0])
      print("\n")
      print(f"El dataset {name} contiene {data.shape[0]} filas y {data.shape[1]} columnas")
      print("\n")

      print("Muestreo de 10 registros aleatorios")
      print("-----------------------------------")
      print("\n")
      print(data.sample(10))
      print("\n")

      print("Columnas, tipo de datos y cantidad de no nulos")
      print("----------------------------------------------")
      print("\n")
      print(data.info())
      print("\n")

      print("Valores perdidos en el dataset :")
      print("--------------------------------")
      sise.append(data.size)
      nas.append(data.isna().sum(axis=0).sum())
      print("\n")
      print(data.isna().sum(axis=0))
      print("\n")
      print("+--------------------------------------+")
      print("| M A P A    D E    C A L O R   DE  NAs|")
      print("+--------------------------------------+")
      print("\n")
      plt.figure(figsize=(27,5))
      mapa = sns.heatmap(data.isna())
      plt.show()


      print("Revisión de algun campo fecha")
      print("------------------------------")
      print("\n")
      columnas = data.columns
      fecs = [col for col in columnas if "date" in col or "stamp" in col]
      for campo in fecs:
        try:
          data[campo]=pd.to_datetime(data[campo],errors="raise")
        except:
          pass

      if fecs :
          data.info()
      else:
          print(f"El archivo {name} no posee campos de tipo Date.")

      print("\n")
      print("||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||")
      print("||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||")
# Out:
# Tamaño del dataset
# ------------------
#
#
# El dataset user_id contiene 25770 filas y 3 columnas
#
#
# Muestreo de 10 registros aleatorios
# -----------------------------------
#
#
#                  user_id                                           user_url  \
# 21347           maxxgame              http://steamcommunity.com/id/maxxgame
# 4031             note551               http://steamcommunity.com/id/note551
# 13965          LTjohnsen             http://steamcommunity.com/id/LTjohnsen
# 18171        pedro6dedos           http://steamcommunity.com/id/pedro6dedos
# 3116   76561198057065903  http://steamcommunity.com/profiles/76561198057...
# 10300      Blueninja_101         http://steamcommunity.com/id/Blueninja_101
# 9574   76561198079368052  http://steamcommunity.com/profiles/76561198079...
# 199    76561198055767971  http://steamcommunity.com/profiles/76561198055...
# 2929     LoveFayeForever       http://steamcommunity.com/id/LoveFayeForever
# 5068   76561198052786944  http://steamcommunity.com/profiles/76561198052...
#
#                                                 Analisis
# 21347                        ['242760;2014-6-26;True;2']
# 4031   ['730;2014-12-19;True;1', '72850;2014-9-13;Tru...
# 13965  ['230050;2012-2-20;True;1', '238460;2014-7-7;T...
# 18171                       ['252490;2015-12-24;True;1']
# 3116   ['310380;2012-2-1;True;2', '222880;2014-4-1;Tr...
# 10300                        ['224260;2014-1-10;True;2']
# 9574                          ['6060;2013-12-11;True;2']
# 199                         ['247730;2015-6-10;False;0']
# 2929   ['304270;2014-9-23;True;2', '440;2014-8-7;True...
# 5068   ['42700;2014-7-10;True;1', '22300;2012-3-29;Tr...
#
#
# Columnas, tipo de datos y cantidad de no nulos
# ----------------------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25770 entries, 0 to 25769
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   25770 non-null  object
#  1   user_url  25770 non-null  object
#  2   Analisis  25770 non-null  object
# dtypes: object(3)
# memory usage: 604.1+ KB
# None
#
#
# Valores perdidos en el dataset :
# --------------------------------
#
#
# user_id     0
# user_url    0
# Analisis    0
# dtype: int64
#
#
# +--------------------------------------+
# | M A P A    D E    C A L O R   DE  NAs|
# +--------------------------------------+
# Revisión de algun campo fecha
# ------------------------------
#
#
# El archivo user_id no posee campos de tipo Date.
#
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Tamaño del dataset
# ------------------
#
#
# El dataset user_url contiene 25770 filas y 3 columnas
#
#
# Muestreo de 10 registros aleatorios
# -----------------------------------
#
#
#                  user_id                                           user_url  \
# 2046            Hispania              http://steamcommunity.com/id/Hispania
# 7788       ThereSheBlows         http://steamcommunity.com/id/ThereSheBlows
# 6659   76561198043880297  http://steamcommunity.com/profiles/76561198043...
# 10962  76561198028908163  http://steamcommunity.com/profiles/76561198028...
# 19052           froijaye              http://steamcommunity.com/id/froijaye
# 12973          itsfilfyd             http://steamcommunity.com/id/itsfilfyd
# 3647   76561198080194046  http://steamcommunity.com/profiles/76561198080...
# 15949  76561198046684086  http://steamcommunity.com/profiles/76561198046...
# 17857  76561198024894178  http://steamcommunity.com/profiles/76561198024...
# 14232  76561198043802521  http://steamcommunity.com/profiles/76561198043...
#
#                                                 Analisis
# 2046                        ['230290;2015-8-26;False;2']
# 7788   ['48705;2015-2-6;True;2', '4000;2014-10-3;True...
# 6659   ['22380;2014-7-17;True;1', '35450;2013-8-24;Tr...
# 10962                        ['241910;2012-6-25;True;2']
# 19052  ['304930;2014-8-7;True;2', '113200;2015-10-14;...
# 12973  ['274940;2015-7-9;True;0', '29800;2015-6-2;Tru...
# 3647                            ['440;2015-7-15;True;1']
# 15949  ['204300;2014-8-11;True;2', '211820;2015-1-24;...
# 17857  ['238750;2014-7-26;True;0', '234650;2013-12-14...
# 14232                        ['104900;2014-2-25;True;2']
#
#
# Columnas, tipo de datos y cantidad de no nulos
# ----------------------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25770 entries, 0 to 25769
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   25770 non-null  object
#  1   user_url  25770 non-null  object
#  2   Analisis  25770 non-null  object
# dtypes: object(3)
# memory usage: 604.1+ KB
# None
#
#
# Valores perdidos en el dataset :
# --------------------------------
#
#
# user_id     0
# user_url    0
# Analisis    0
# dtype: int64
#
#
# +--------------------------------------+
# | M A P A    D E    C A L O R   DE  NAs|
# +--------------------------------------+
# Revisión de algun campo fecha
# ------------------------------
#
#
# El archivo user_url no posee campos de tipo Date.
#
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Tamaño del dataset
# ------------------
#
#
# El dataset Analisis contiene 25770 filas y 3 columnas
#
#
# Muestreo de 10 registros aleatorios
# -----------------------------------
#
#
#                  user_id                                           user_url  \
# 3466   76561198036740385  http://steamcommunity.com/profiles/76561198036...
# 6985          mrjaksauce            http://steamcommunity.com/id/mrjaksauce
# 16284    SirMasterBaiter       http://steamcommunity.com/id/SirMasterBaiter
# 16423  76561198089300394  http://steamcommunity.com/profiles/76561198089...
# 5779         EmperorJake           http://steamcommunity.com/id/EmperorJake
# 21159  76561198061503548  http://steamcommunity.com/profiles/76561198061...
# 1489            macky121              http://steamcommunity.com/id/macky121
# 24783         swag-iwnl-            http://steamcommunity.com/id/swag-iwnl-
# 3957              codedj                http://steamcommunity.com/id/codedj
# 6526      ParalysedChook        http://steamcommunity.com/id/ParalysedChook
#
#                                                 Analisis
# 3466                          ['221260;2013-6-5;True;2']
# 6985   ['7510;2013-10-18;True;2', '104900;2014-3-9;Tr...
# 16284                        ['236390;2015-3-19;True;2']
# 16423                          ['4000;2014-2-13;True;2']
# 5779                        ['259080;2013-12-11;True;2']
# 21159  ['372000;2012-5-31;True;0', '550;2015-1-9;True...
# 1489                            ['4000;2015-3-7;True;2']
# 24783  ['24840;2014-7-15;True;2', '31280;2014-4-25;Tr...
# 3957                         ['294100;2012-7-16;True;0']
# 6526   ['105600;2015-1-11;True;1', '219150;2015-1-11;...
#
#
# Columnas, tipo de datos y cantidad de no nulos
# ----------------------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25770 entries, 0 to 25769
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   25770 non-null  object
#  1   user_url  25770 non-null  object
#  2   Analisis  25770 non-null  object
# dtypes: object(3)
# memory usage: 604.1+ KB
# None
#
#
# Valores perdidos en el dataset :
# --------------------------------
#
#
# user_id     0
# user_url    0
# Analisis    0
# dtype: int64
#
#
# +--------------------------------------+
# | M A P A    D E    C A L O R   DE  NAs|
# +--------------------------------------+
# Revisión de algun campo fecha
# ------------------------------
#
#
# El archivo Analisis no posee campos de tipo Date.
#
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Tamaño del dataset
# ------------------
#
#
# El dataset user_id contiene 7310 filas y 5 columnas
#
#
# Muestreo de 10 registros aleatorios
# -----------------------------------
#
#
#                    user_id  items_count           steam_id  \
# 4274     76561197978298031            0  76561197978298031
# 5867     76561198047295171          191  76561198047295171
# 4156          seanluvsfood           61  76561198063139341
# 820      76561198105387448            0  76561198105387448
# 4456  IAMYOUDIDYOUKNOWTHAT           80  76561198058260614
# 2457     76561198064263411           12  76561198064263411
# 204              xoFushiox           49  76561198080439887
# 3009     76561198073468161           23  76561198073468161
# 6489     76561198006537919            0  76561198006537919
# 4287     76561198190836507          150  76561198190836507
#
#                                                user_url  \
# 4274  http://steamcommunity.com/profiles/76561197978...
# 5867  http://steamcommunity.com/profiles/76561198047...
# 4156          http://steamcommunity.com/id/seanluvsfood
# 820   http://steamcommunity.com/profiles/76561198105...
# 4456  http://steamcommunity.com/id/IAMYOUDIDYOUKNOWTHAT
# 2457  http://steamcommunity.com/profiles/76561198064...
# 204              http://steamcommunity.com/id/xoFushiox
# 3009  http://steamcommunity.com/profiles/76561198073...
# 6489  http://steamcommunity.com/profiles/76561198006...
# 4287  http://steamcommunity.com/profiles/76561198190...
#
#                                                  juegos
# 4274                                                 []
# 5867  ['220;Half-Life 2;0;83', '340;Half-Life 2: Los...
# 4156  ['4000;Garrys Mod;0;40162', '13540;Tom Clancys...
# 820                                                  []
# 4456  ['4000;Garrys Mod;0;3709', '400;Portal;0;440',...
# 2457  ['33910;Arma 2;0;63', '33930;Arma 2: Operation...
# 204   ['10;Counter-Strike;0;4523', '80;Counter-Strik...
# 3009  ['6880;Just Cause;0;122', '500;Left 4 Dead;0;0...
# 6489                                                 []
# 4287  ['240;Counter-Strike: Source;0;34', '300;Day o...
#
#
# Columnas, tipo de datos y cantidad de no nulos
# ----------------------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7310 entries, 0 to 7309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      7310 non-null   object
#  1   items_count  7310 non-null   int64
#  2   steam_id     7310 non-null   int64
#  3   user_url     7310 non-null   object
#  4   juegos       7310 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 285.7+ KB
# None
#
#
# Valores perdidos en el dataset :
# --------------------------------
#
#
# user_id        0
# items_count    0
# steam_id       0
# user_url       0
# juegos         0
# dtype: int64
#
#
# +--------------------------------------+
# | M A P A    D E    C A L O R   DE  NAs|
# +--------------------------------------+
# Revisión de algun campo fecha
# ------------------------------
#
#
# El archivo user_id no posee campos de tipo Date.
#
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Tamaño del dataset
# ------------------
#
#
# El dataset user_url contiene 7310 filas y 5 columnas
#
#
# Muestreo de 10 registros aleatorios
# -----------------------------------
#
#
#                 user_id  items_count           steam_id  \
# 3185  76561197961236919            0  76561197961236919
# 474   76561198082614708           28  76561198082614708
# 2689        Snoresville           79  76561198054211176
# 2718  76561198160470970            2  76561198160470970
# 3770            xXLeoXx           22  76561198088765640
# 1452  76561197980614542          139  76561197980614542
# 5451  76561198068688231           57  76561198068688231
# 5046  76561198042858322            0  76561198042858322
# 5150  76561198064681833           98  76561198064681833
# 7183  76561198013922033           81  76561198013922033
#
#                                                user_url  \
# 3185  http://steamcommunity.com/profiles/76561197961...
# 474   http://steamcommunity.com/profiles/76561198082...
# 2689           http://steamcommunity.com/id/Snoresville
# 2718  http://steamcommunity.com/profiles/76561198160...
# 3770               http://steamcommunity.com/id/xXLeoXx
# 1452  http://steamcommunity.com/profiles/76561197980...
# 5451  http://steamcommunity.com/profiles/76561198068...
# 5046  http://steamcommunity.com/profiles/76561198042...
# 5150  http://steamcommunity.com/profiles/76561198064...
# 7183  http://steamcommunity.com/profiles/76561198013...
#
#                                                  juegos
# 3185                                                 []
# 474   ['4000;Garrys Mod;1166;1166', '205790;Dota 2 T...
# 2689  ['4000;Garrys Mod;0;131', '11390;Crash Time II...
# 2718    ['205790;Dota 2 Test;0;0', '315640;Dizzel;0;0']
# 3770  ['6060;STAR WARS‚Ñ¢ Battlefront‚Ñ¢ II;0;20', '...
# 1452  ['220;Half-Life 2;0;3908', '340;Half-Life 2: L...
# 5451  ['220;Half-Life 2;0;1490', '340;Half-Life 2: L...
# 5046                                                 []
# 5150  ['240;Counter-Strike: Source;0;379', '4000;Gar...
# 7183  ['4000;Garrys Mod;38;19066', '320;Half-Life 2:...
#
#
# Columnas, tipo de datos y cantidad de no nulos
# ----------------------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7310 entries, 0 to 7309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      7310 non-null   object
#  1   items_count  7310 non-null   int64
#  2   steam_id     7310 non-null   int64
#  3   user_url     7310 non-null   object
#  4   juegos       7310 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 285.7+ KB
# None
#
#
# Valores perdidos en el dataset :
# --------------------------------
#
#
# user_id        0
# items_count    0
# steam_id       0
# user_url       0
# juegos         0
# dtype: int64
#
#
# +--------------------------------------+
# | M A P A    D E    C A L O R   DE  NAs|
# +--------------------------------------+
# Revisión de algun campo fecha
# ------------------------------
#
#
# El archivo user_url no posee campos de tipo Date.
#
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Tamaño del dataset
# ------------------
#
#
# El dataset Analisis contiene 7310 filas y 5 columnas
#
#
# Muestreo de 10 registros aleatorios
# -----------------------------------
#
#
#                 user_id  items_count           steam_id  \
# 1080         IchMasKung          115  76561198078500447
# 5851         Beast_m0de           37  76561198084711261
# 2504              PALYI           18  76561198073034520
# 2321        FireInLatin          141  76561198083673560
# 3779  76561198046981980          109  76561198046981980
# 638   asianturtlefrenzy           87  76561198100436187
# 5381  76561198058892496           73  76561198058892496
# 1563          dragonxx5           32  76561198081305375
# 3410  76561197986529825           70  76561197986529825
# 6622  76561198031336086           63  76561198031336086
#
#                                                user_url  \
# 1080            http://steamcommunity.com/id/IchMasKung
# 5851            http://steamcommunity.com/id/Beast_m0de
# 2504                 http://steamcommunity.com/id/PALYI
# 2321           http://steamcommunity.com/id/FireInLatin
# 3779  http://steamcommunity.com/profiles/76561198046...
# 638      http://steamcommunity.com/id/asianturtlefrenzy
# 5381  http://steamcommunity.com/profiles/76561198058...
# 1563             http://steamcommunity.com/id/dragonxx5
# 3410  http://steamcommunity.com/profiles/76561197986...
# 6622  http://steamcommunity.com/profiles/76561198031...
#
#                                                  juegos
# 1080  ['4000;Garrys Mod;0;2364', '220;Half-Life 2;0;...
# 5851  ['240;Counter-Strike: Source;0;270', '4000;Gar...
# 2504  ['38830;CrimeCraft GangWars;0;1', '99900;Spira...
# 2321  ['220;Half-Life 2;0;193', '340;Half-Life 2: Lo...
# 3779  ['3830;Psychonauts;0;0', '4000;Garrys Mod;0;33...
# 638   ['4000;Garrys Mod;0;261', '11390;Crash Time II...
# 5381  ['240;Counter-Strike: Source;0;51', '4000;Garr...
# 1563  ['220;Half-Life 2;0;640', '340;Half-Life 2: Lo...
# 3410  ['240;Counter-Strike: Source;0;1181', '300;Day...
# 6622  ['240;Counter-Strike: Source;0;79', '4000;Garr...
#
#
# Columnas, tipo de datos y cantidad de no nulos
# ----------------------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7310 entries, 0 to 7309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      7310 non-null   object
#  1   items_count  7310 non-null   int64
#  2   steam_id     7310 non-null   int64
#  3   user_url     7310 non-null   object
#  4   juegos       7310 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 285.7+ KB
# None
#
#
# Valores perdidos en el dataset :
# --------------------------------
#
#
# user_id        0
# items_count    0
# steam_id       0
# user_url       0
# juegos         0
# dtype: int64
#
#
# +--------------------------------------+
# | M A P A    D E    C A L O R   DE  NAs|
# +--------------------------------------+
# Revisión de algun campo fecha
# ------------------------------
#
#
# El archivo Analisis no posee campos de tipo Date.
#
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Tamaño del dataset
# ------------------
#
#
# El dataset user_id contiene 22520 filas y 13 columnas
#
#
# Muestreo de 10 registros aleatorios
# -----------------------------------
#
#
#                                    publisher  \
# 18235                        Jochen Mistiaen
# 4271   United Independent Entertainment GmbH
# 675                          Giants Software
# 3521                             The Foundry
# 17932                    Iceberg Interactive
# 17020                  Aterdux Entertainment
# 5835                          Immersed Games
# 6738                              Activision
# 15575                              DXF Games
# 14906                   Flying Carpets Games
#
#                                                 app_name  \
# 18235                                         Malebolgia
# 4271                              New York Bus Simulator
# 675              Farming Simulator 2011 Equipment Pack 3
# 3521                                       MODO indie 10
# 17932                        Starpoint Gemini 2: Origins
# 17020          Legends of Eisenwald: Road to Iron Forest
# 5835                                         Tyto Online
# 6738                                    Call to Power II
# 15575                                  Just a Cleric OST
# 14906  The Girl and the Robot - Music and Digital Art...
#
#                                                    title  \
# 18235                                         Malebolgia
# 4271                              New York Bus Simulator
# 675              Farming Simulator 2011 Equipment Pack 3
# 3521                                       MODO indie 10
# 17932                        Starpoint Gemini 2: Origins
# 17020          Legends of Eisenwald: Road to Iron Forest
# 5835                                         Tyto Online
# 6738                                    Call to Power II
# 15575                                  Just a Cleric OST
# 14906  The Girl and the Robot - Music and Digital Art...
#
#                                                      url release_date  \
# 18235  http://store.steampowered.com/app/318860/Maleb...   2015-05-06
# 4271   http://store.steampowered.com/app/446480/New_Y...   2016-03-04
# 675    http://store.steampowered.com/app/90208/Farmin...   2011-09-29
# 3521   http://store.steampowered.com/app/401090/MODO_...   2015-09-24
# 17932  http://store.steampowered.com/app/371060/Starp...   2015-06-10
# 17020  http://store.steampowered.com/app/416750/Legen...   2015-11-05
# 5835   http://store.steampowered.com/app/544290/Tyto_...   2016-11-25
# 6738   http://store.steampowered.com/app/572050/Call_...   2000-10-20
# 15575  http://store.steampowered.com/app/479270/Just_...   2016-05-31
# 14906  http://store.steampowered.com/app/506720/The_G...   2016-08-12
#
#                                                     tags  \
# 18235         ['Adventure', 'Indie', 'Action', 'Horror']
# 4271                                      ['Simulation']
# 675                                       ['Simulation']
# 3521   ['Animation & Modeling', 'Design & Illustration']
# 17932  ['Action', 'Simulation', 'RPG', 'Space Sim', '...
# 17020          ['Strategy', 'Adventure', 'RPG', 'Indie']
# 5835   ['Early Access', 'Education', 'Family Friendly...
# 6738                 ['Strategy', 'Turn-Based Strategy']
# 15575                         ['Action', 'RPG', 'Indie']
# 14906            ['Action', 'Adventure', 'RPG', 'Indie']
#
#                                              reviews_url  \
# 18235  http://steamcommunity.com/app/318860/reviews/?...
# 4271   http://steamcommunity.com/app/446480/reviews/?...
# 675    http://steamcommunity.com/app/90208/reviews/?b...
# 3521   http://steamcommunity.com/app/401090/reviews/?...
# 17932  http://steamcommunity.com/app/371060/reviews/?...
# 17020  http://steamcommunity.com/app/416750/reviews/?...
# 5835   http://steamcommunity.com/app/544290/reviews/?...
# 6738   http://steamcommunity.com/app/572050/reviews/?...
# 15575  http://steamcommunity.com/app/479270/reviews/?...
# 14906  http://steamcommunity.com/app/506720/reviews/?...
#
#                                                    specs   price  \
# 18235  ['Single-player', 'Steam Achievements', 'Steam...   12.99
# 4271                                   ['Single-player']    4.99
# 675    ['Single-player', 'Multi-player', 'Co-op', 'Do...    6.99
# 3521                                     ['Steam Cloud']  299.99
# 17932  ['Single-player', 'Downloadable Content', 'Ste...   41.99
# 17020  ['Single-player', 'Downloadable Content', 'Ste...    4.99
# 5835      ['Multi-player', 'Online Multi-Player', 'MMO']   24.99
# 6738                                   ['Single-player']    5.99
# 15575  ['Single-player', 'Downloadable Content', 'Ste...    1.99
# 14906  ['Single-player', 'Downloadable Content', 'Par...    3.99
#
#        early_access        id               developer  \
# 18235           0.0  318860.0         Jochen Mistiaen
# 4271            0.0  446480.0  Little Freedom Factory
# 675             0.0   90208.0         Giants Software
# 3521            0.0  401090.0             The Foundry
# 17932           0.0  371060.0  Little Green Men Games
# 17020           0.0  416750.0   Aterdux Entertainment
# 5835            1.0  544290.0          Immersed Games
# 6738            0.0  572050.0              Activision
# 15575           0.0  479270.0               DXF Games
# 14906           0.0  506720.0    Flying Carpets Games
#
#                                                  generos
# 18235                 ['Action', ' Adventure', ' Indie']
# 4271                                      ['Simulation']
# 675                                       ['Simulation']
# 3521   ['Animation &amp; Modeling', ' Design &amp; Il...
# 17932                  ['Action', ' RPG', ' Simulation']
# 17020       ['Adventure', ' Indie', ' RPG', ' Strategy']
# 5835   ['Casual', ' Indie', ' Massively Multiplayer',...
# 6738                                        ['Strategy']
# 15575                       ['Action', ' Indie', ' RPG']
# 14906         ['Action', ' Adventure', ' Indie', ' RPG']
#
#
# Columnas, tipo de datos y cantidad de no nulos
# ----------------------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22520 entries, 0 to 22519
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     22520 non-null  object
#  1   app_name      22520 non-null  object
#  2   title         22520 non-null  object
#  3   url           22520 non-null  object
#  4   release_date  22520 non-null  object
#  5   tags          22520 non-null  object
#  6   reviews_url   22520 non-null  object
#  7   specs         22520 non-null  object
#  8   price         22520 non-null  object
#  9   early_access  22520 non-null  float64
#  10  id            22520 non-null  float64
#  11  developer     22520 non-null  object
#  12  generos       22520 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 2.2+ MB
# None
#
#
# Valores perdidos en el dataset :
# --------------------------------
#
#
# publisher       0
# app_name        0
# title           0
# url             0
# release_date    0
# tags            0
# reviews_url     0
# specs           0
# price           0
# early_access    0
# id              0
# developer       0
# generos         0
# dtype: int64
#
#
# +--------------------------------------+
# | M A P A    D E    C A L O R   DE  NAs|
# +--------------------------------------+
# Revisión de algun campo fecha
# ------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22520 entries, 0 to 22519
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     22520 non-null  object
#  1   app_name      22520 non-null  object
#  2   title         22520 non-null  object
#  3   url           22520 non-null  object
#  4   release_date  22520 non-null  object
#  5   tags          22520 non-null  object
#  6   reviews_url   22520 non-null  object
#  7   specs         22520 non-null  object
#  8   price         22520 non-null  object
#  9   early_access  22520 non-null  float64
#  10  id            22520 non-null  float64
#  11  developer     22520 non-null  object
#  12  generos       22520 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 2.2+ MB
#
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Tamaño del dataset
# ------------------
#
#
# El dataset user_url contiene 22520 filas y 13 columnas
#
#
# Muestreo de 10 registros aleatorios
# -----------------------------------
#
#
#                         publisher  \
# 17470         Dimecoin Games, LLC
# 19138  BANDAI NAMCO Entertainment
# 6828      Dovetail Games - Flight
# 9207                    RunServer
# 2006           Trion Worlds, Inc.
# 16270              Picorinne Soft
# 18391                    JAST USA
# 11807                 Tusky Games
# 11238                HexWar Games
# 9561         Black Phoenix Studio
#
#                                                 app_name  \
# 17470                                              Fjall
# 19138  NARUTO SHIPPUDEN: Ultimate Ninja STORM Revolut...
# 6828    FSX Steam Edition: Beechcraft® Duchess 76 Add-On
# 9207                    Insane Cold: Back to the Ice Age
# 2006                    RIFT: Glory of the Ascended Pack
# 16270                                       Battle Crust
# 18391               Littlewitch Romanesque: Editio Regia
# 11807                             Escape From BioStation
# 11238             Hold the Line: The American Revolution
# 9561                                             40 Days
#
#                                                    title  \
# 17470                                              Fjall
# 19138  NARUTO SHIPPUDEN: Ultimate Ninja STORM Revolut...
# 6828    FSX Steam Edition: Beechcraft® Duchess 76 Add-On
# 9207                    Insane Cold: Back to the Ice Age
# 2006                    RIFT: Glory of the Ascended Pack
# 16270                                       Battle Crust
# 18391               Littlewitch Romanesque: Editio Regia
# 11807                             Escape From BioStation
# 11238             Hold the Line: The American Revolution
# 9561                                             40 Days
#
#                                                      url release_date  \
# 17470    http://store.steampowered.com/app/398900/Fjall/   2015-09-19
# 19138  http://store.steampowered.com/app/318710/NARUT...   2014-10-28
# 6828   http://store.steampowered.com/app/556210/FSX_S...   2017-05-04
# 9207   http://store.steampowered.com/app/764010/Insan...   2014-08-27
# 2006   http://store.steampowered.com/app/310280/RIFT_...   2014-06-19
# 16270  http://store.steampowered.com/app/444710/Battl...   2016-02-25
# 18391  http://store.steampowered.com/app/349300/Littl...   2015-04-03
# 11807  http://store.steampowered.com/app/391650/Escap...   2017-07-25
# 11238  http://store.steampowered.com/app/657500/Hold_...   2017-08-18
# 9561   http://store.steampowered.com/app/737600/40_Days/   2017-11-28
#
#                                                     tags  \
# 17470                      ['Action', 'Indie', 'Casual']
# 19138                            ['Action', 'Adventure']
# 6828                                      ['Simulation']
# 9207   ['Casual', 'Indie', 'Hidden Object', 'Point & ...
# 2006    ['RPG', 'Massively Multiplayer', 'Free to Play']
# 16270                ['Action', 'Indie', "Shoot 'Em Up"]
# 18391  ['Visual Novel', 'Anime', 'Simulation', 'Strat...
# 11807                   ['Action', 'Indie', 'Adventure']
# 11238                                       ['Strategy']
# 9561   ['Strategy', 'Indie', 'Simulation', 'Management']
#
#                                              reviews_url  \
# 17470  http://steamcommunity.com/app/398900/reviews/?...
# 19138  http://steamcommunity.com/app/318710/reviews/?...
# 6828   http://steamcommunity.com/app/556210/reviews/?...
# 9207   http://steamcommunity.com/app/764010/reviews/?...
# 2006   http://steamcommunity.com/app/310280/reviews/?...
# 16270  http://steamcommunity.com/app/444710/reviews/?...
# 18391  http://steamcommunity.com/app/349300/reviews/?...
# 11807  http://steamcommunity.com/app/391650/reviews/?...
# 11238  http://steamcommunity.com/app/657500/reviews/?...
# 9561   http://steamcommunity.com/app/737600/reviews/?...
#
#                                                    specs  price  early_access  \
# 17470       ['Single-player', 'Full controller support']   2.99           0.0
# 19138  ['Single-player', 'Multi-player', 'Downloadabl...   1.99           0.0
# 6828   ['Single-player', 'Multi-player', 'Downloadabl...  16.99           0.0
# 9207            ['Single-player', 'Steam Trading Cards']   1.99           0.0
# 2006   ['Single-player', 'Multi-player', 'MMO', 'Co-o...  99.99           0.0
# 16270    ['Single-player', 'Partial Controller Support']   7.99           0.0
# 18391  ['Single-player', 'Steam Trading Cards', 'Stea...  14.99           0.0
# 11807  ['Single-player', 'Steam Achievements', 'Steam...   2.99           0.0
# 11238                                  ['Single-player']  14.99           0.0
# 9561             ['Single-player', 'Steam Achievements']   6.99           0.0
#
#              id                developer  \
# 17470  398900.0          dimecoin,Bestow
# 19138  318710.0  CyberConnect2 Co., Ltd.
# 6828   556210.0              Just Flight
# 9207   764010.0               Mysterytag
# 2006   310280.0             Trion Worlds
# 16270  444710.0           Picorinne Soft
# 18391  349300.0              Littlewitch
# 11807  391650.0              Tusky Games
# 11238  657500.0             HexWar Games
# 9561   737600.0     Black Phoenix Studio
#
#                                                  generos
# 17470                    ['Action', ' Casual', ' Indie']
# 19138                           ['Action', ' Adventure']
# 6828                                      ['Simulation']
# 9207                                ['Casual', ' Indie']
# 2006   ['Free to Play', ' Massively Multiplayer', ' R...
# 16270                               ['Action', ' Indie']
# 18391             ['Casual', ' Simulation', ' Strategy']
# 11807                 ['Action', ' Adventure', ' Indie']
# 11238                                       ['Strategy']
# 9561               ['Indie', ' Simulation', ' Strategy']
#
#
# Columnas, tipo de datos y cantidad de no nulos
# ----------------------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22520 entries, 0 to 22519
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     22520 non-null  object
#  1   app_name      22520 non-null  object
#  2   title         22520 non-null  object
#  3   url           22520 non-null  object
#  4   release_date  22520 non-null  object
#  5   tags          22520 non-null  object
#  6   reviews_url   22520 non-null  object
#  7   specs         22520 non-null  object
#  8   price         22520 non-null  object
#  9   early_access  22520 non-null  float64
#  10  id            22520 non-null  float64
#  11  developer     22520 non-null  object
#  12  generos       22520 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 2.2+ MB
# None
#
#
# Valores perdidos en el dataset :
# --------------------------------
#
#
# publisher       0
# app_name        0
# title           0
# url             0
# release_date    0
# tags            0
# reviews_url     0
# specs           0
# price           0
# early_access    0
# id              0
# developer       0
# generos         0
# dtype: int64
#
#
# +--------------------------------------+
# | M A P A    D E    C A L O R   DE  NAs|
# +--------------------------------------+
# Revisión de algun campo fecha
# ------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22520 entries, 0 to 22519
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     22520 non-null  object
#  1   app_name      22520 non-null  object
#  2   title         22520 non-null  object
#  3   url           22520 non-null  object
#  4   release_date  22520 non-null  object
#  5   tags          22520 non-null  object
#  6   reviews_url   22520 non-null  object
#  7   specs         22520 non-null  object
#  8   price         22520 non-null  object
#  9   early_access  22520 non-null  float64
#  10  id            22520 non-null  float64
#  11  developer     22520 non-null  object
#  12  generos       22520 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 2.2+ MB
#
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Tamaño del dataset
# ------------------
#
#
# El dataset Analisis contiene 22520 filas y 13 columnas
#
#
# Muestreo de 10 registros aleatorios
# -----------------------------------
#
#
#                     publisher                               app_name  \
# 10138  Daedalic Entertainment                    AER Memories of Old
# 1031                  Ubisoft  Rocksmith - The Temptations - My Girl
# 17586             AGM PLAYISM                   One Way Heroics Plus
# 16635       SMD Gaming Studio                                 Furfly
# 9342          Pixel Six Games                         EX0: Dark Moon
# 4668               Pera Games                               Overfall
# 5993                   8Floor  Gnomes Garden 3: The thief of castles
# 19449            Ludeme Games                    Chess 2: The Sequel
# 21964         Electronic Arts         Dragon Age™: Origins Awakening
# 15962      Snapjaw Games GmbH                   The Fifth Expedition
#
#                                        title  \
# 10138                    AER Memories of Old
# 1031   Rocksmith - The Temptations - My Girl
# 17586                   One Way Heroics Plus
# 16635                                 Furfly
# 9342                          EX0: Dark Moon
# 4668                                Overfall
# 5993   Gnomes Garden 3: The thief of castles
# 19449                    Chess 2: The Sequel
# 21964         Dragon Age™: Origins Awakening
# 15962                   The Fifth Expedition
#
#                                                      url release_date  \
# 10138  http://store.steampowered.com/app/331870/AER_M...   2017-10-25
# 1031   http://store.steampowered.com/app/206155/Rocks...   2012-10-16
# 17586  http://store.steampowered.com/app/352840/One_W...   2015-08-17
# 16635   http://store.steampowered.com/app/429040/Furfly/   2015-12-18
# 9342   http://store.steampowered.com/app/736180/EX0_D...   2017-12-08
# 4668   http://store.steampowered.com/app/402310/Overf...   2016-03-01
# 5993   http://store.steampowered.com/app/546200/Gnome...   2016-12-22
# 19449  http://store.steampowered.com/app/314340/Chess...   2014-08-19
# 21964  http://store.steampowered.com/app/47730/Dragon...   2010-03-16
# 15962  http://store.steampowered.com/app/453030/The_F...   2016-04-07
#
#                                                     tags  \
# 10138  ['Adventure', 'Indie', 'Exploration', 'Open Wo...
# 1031                            ['Casual', 'Simulation']
# 17586  ['Indie', 'RPG', 'Rogue-like', 'Replay Value',...
# 16635                                ['Indie', 'Action']
# 9342                              ['Adventure', 'Indie']
# 4668   ['RPG', 'Strategy', 'Turn-Based Combat', 'Rogu...
# 5993                              ['Strategy', 'Casual']
# 19449  ['Chess', 'Strategy', 'Indie', 'Sports', 'Boar...
# 21964  ['RPG', 'Fantasy', 'Multiple Endings', 'Real-T...
# 15962  ['Early Access', 'Survival', 'Strategy', 'Acti...
#
#                                              reviews_url  \
# 10138  http://steamcommunity.com/app/331870/reviews/?...
# 1031   http://steamcommunity.com/app/206155/reviews/?...
# 17586  http://steamcommunity.com/app/352840/reviews/?...
# 16635  http://steamcommunity.com/app/429040/reviews/?...
# 9342   http://steamcommunity.com/app/736180/reviews/?...
# 4668   http://steamcommunity.com/app/402310/reviews/?...
# 5993   http://steamcommunity.com/app/546200/reviews/?...
# 19449  http://steamcommunity.com/app/314340/reviews/?...
# 21964  http://steamcommunity.com/app/47730/reviews/?b...
# 15962  http://steamcommunity.com/app/453030/reviews/?...
#
#                                                    specs  price  early_access  \
# 10138  ['Single-player', 'Steam Achievements', 'Full ...   2.99           0.0
# 1031   ['Single-player', 'Shared/Split Screen', 'Down...   2.99           0.0
# 17586  ['Single-player', 'Downloadable Content', 'Ste...   6.49           0.0
# 16635    ['Single-player', 'Partial Controller Support']   0.99           0.0
# 9342                                   ['Single-player']   0.99           0.0
# 4668   ['Single-player', 'Steam Achievements', 'Steam...  14.99           0.0
# 5993   ['Single-player', 'Steam Achievements', 'Steam...   4.99           0.0
# 19449  ['Single-player', 'Multi-player', 'Cross-Platf...   5.99           0.0
# 21964                                  ['Single-player']   9.99           0.0
# 15962  ['Single-player', 'Steam Achievements', 'Steam...   9.99           1.0
#
#              id                  developer  \
# 10138  331870.0              Forgotten Key
# 1031   206155.0    Ubisoft - San Francisco
# 17586  352840.0               Smoking WOLF
# 16635  429040.0          SMD Gaming Studio
# 9342   736180.0            Pixel Six Games
# 4668   402310.0                 Pera Games
# 5993   546200.0                    Creobit
# 19449  314340.0  Ludeme Games,Sirlin Games
# 21964   47730.0                    BioWare
# 15962  453030.0         Snapjaw Games GmbH
#
#                                                  generos
# 10138                            ['Adventure', ' Indie']
# 1031                           ['Casual', ' Simulation']
# 17586                                  ['Indie', ' RPG']
# 16635                               ['Action', ' Indie']
# 9342                             ['Adventure', ' Indie']
# 4668                      ['Indie', ' RPG', ' Strategy']
# 5993                             ['Casual', ' Strategy']
# 19449                  ['Indie', ' Sports', ' Strategy']
# 21964                                            ['RPG']
# 15962  ['Action', ' Indie', ' Strategy', ' Early Acce...
#
#
# Columnas, tipo de datos y cantidad de no nulos
# ----------------------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22520 entries, 0 to 22519
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     22520 non-null  object
#  1   app_name      22520 non-null  object
#  2   title         22520 non-null  object
#  3   url           22520 non-null  object
#  4   release_date  22520 non-null  object
#  5   tags          22520 non-null  object
#  6   reviews_url   22520 non-null  object
#  7   specs         22520 non-null  object
#  8   price         22520 non-null  object
#  9   early_access  22520 non-null  float64
#  10  id            22520 non-null  float64
#  11  developer     22520 non-null  object
#  12  generos       22520 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 2.2+ MB
# None
#
#
# Valores perdidos en el dataset :
# --------------------------------
#
#
# publisher       0
# app_name        0
# title           0
# url             0
# release_date    0
# tags            0
# reviews_url     0
# specs           0
# price           0
# early_access    0
# id              0
# developer       0
# generos         0
# dtype: int64
#
#
# +--------------------------------------+
# | M A P A    D E    C A L O R   DE  NAs|
# +--------------------------------------+
# Revisión de algun campo fecha
# ------------------------------
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22520 entries, 0 to 22519
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     22520 non-null  object
#  1   app_name      22520 non-null  object
#  2   title         22520 non-null  object
#  3   url           22520 non-null  object
#  4   release_date  22520 non-null  object
#  5   tags          22520 non-null  object
#  6   reviews_url   22520 non-null  object
#  7   specs         22520 non-null  object
#  8   price         22520 non-null  object
#  9   early_access  22520 non-null  float64
#  10  id            22520 non-null  float64
#  11  developer     22520 non-null  object
#  12  generos       22520 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 2.2+ MB
#
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
